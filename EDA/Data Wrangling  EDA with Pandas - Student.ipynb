# %% [markdown]
# ![logo-2.png](attachment:logo-2.png)

# %% [markdown]
# In this project, we will analyze human resources data by performing data wrangling & EDA.
#
# We will learn how to:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Uncover the factors that cause employees to leave and explore key questions like 'show a breakdown of distance from home by job role and leave' or 'compare average monthly income by education and leaving'. This is a fictional dataset created by IBM data scientists.

# %% [markdown]
# # CODING TASK #1. IMPORT DATASET AND PERFORM BASIC STATISTICAL DATA ANALYSIS

# %% [markdown]
# - **Import Pandas Library**
#
# - **Force Pandas to display all rows and columns**
#
# - **Let's read a CSV file using Pandas as follows**
#
# - **Let's obtain the datatype**
#
# - **you can view the first couple of rows using .head()**
#
# - **you can view the last couple of rows using .tail()**
#
# - **Calculate the average values for employee_df dataframe**
#
# - **35 features in total**
#
# - **Obtain a Statistical Summary about the data**

# %% [markdown]
# * **<font color="red">Age</font>** : Çalışanın yaşı
#
# * **<font color="red">Attrition</font>** : Çalışanın işten ayrılma durumu (Yes veya No)
#
# * **<font color="red">BusinessTravel</font>** : Çalışanın iş seyahati sıklığı (Travel_Rarely, Travel_Frequently veya Non-Travel)
#
# * **<font color="red">DailyRate</font>** : Çalışanın günlük ücreti
#
# * **<font color="red">Department</font>** : Çalışanın çalıştığı departman (Sales, Research & Development veya Human Resources)
#
# * **<font color="red">DistanceFromHome</font>** : Çalışanın evinden iş yerine olan mesafesi (km)
#
# * **<font color="red">Education</font>** : Çalışanın eğitim seviyesi (1: Below College, 2: College, 3: Bachelor, 4: Master, 5: Doctor)
#
# * **<font color="red">EducationField</font>** : Çalışanın eğitim aldığı alan(Life Sciences, Other, Medical, Marketing, Technical Degree veya Human Resources)
#
# * **<font color="red">EmployeeCount</font>** : Çalışan sayısı (her zaman 1)
#
# * **<font color="red">EmployeeNumber</font>** : Çalışanın numarası
#
# * **<font color="red">EnvironmentSatisfaction</font>** : Çalışanın çalışma ortamından memnuniyeti (1: Low, 2: Medium, 3: High, 4: Very High)
#
# * **<font color="red">Gender</font>** : Çalışanın cinsiyeti (Male veya Female)
#
# * **<font color="red">HourlyRate</font>** : Çalışanın saatlik ücreti
#
# * **<font color="red">JobInvolvement</font>** : Çalışanın işe katılımı (1: Low, 2: Medium, 3: High, 4: Very High)
#
# * **<font color="red">JobLevel</font>** : Çalışanın iş seviyesi (1 ila 5 arasında bir tam sayı)
#
# * **<font color="red">JobRole</font>** : Çalışanın iş rolü (Sales Executive, Research Scientist, Laboratory Technician, Manufacturing Director, Healthcare Representative, Manager, Sales Representative,  Research Director, Human Resources)
#
# * **<font color="red">JobSatisfaction</font>** : Çalışanın işinden memnuniyeti (1: Low, 2: Medium, 3: High, 4: Very High)
#
# * **<font color="red">MaritalStatus</font>** : Çalışanın medeni durumu (Single, Married veya Divorced)
#
# * **<font color="red">MonthlyIncome</font>** : Çalışanın aylık geliri
#
# * **<font color="red">MonthlyRate</font>** : Çalışanın aylık oranı
#
# * **<font color="red">NumCompaniesWorked</font>** : Çalışanın daha önce çalıştığı şirket sayısı
#
# * **<font color="red">Over18</font>** : Çalışanın 18 yaşından büyük olup olmadığı (Y veya N)
#
# * **<font color="red">OverTime</font>** : Çalışanın fazla mesai yapmış olup olmadığı (Yes veya No)
#
# * **<font color="red">PercentSalaryHike</font>** : Çalışanın maaş artış yüzdesi
#
# * **<font color="red">PerformanceRating</font>** : Çalışanın performans derecesi (1: Low, 2: Good, 3: Excellent, 4: Outstanding)
#
# * **<font color="red">RelationshipSatisfaction</font>** : Çalışanın ilişkilerinden memnuniyeti (1: Low, 2: Medium, 3: High, 4: Very High)
#
# * **<font color="red">StandardHours</font>** : Çalışanın standart saatleri (her zaman 80)
#
# * **<font color="red">StockOptionLevel</font>** : Çalışanın hisse opsiyonu seviyesi (0 ila 3 arasında bir tam sayı)
#
# * **<font color="red">TotalWorkingYears</font>** : Çalışanın toplam çalışma yılları
#
# * **<font color="red">TrainingTimesLastYear</font>** : Çalışanın son yılda aldığı eğitim sayısı
#
# * **<font color="red">WorkLifeBalance</font>** : Çalışanın iş-yaşam dengesi (1: Bad, 2: Good, 3: Better, 4: Best)
#
# * **<font color="red">YearsAtCompany</font>** : Çalışanın şirketteki yılları
#
# * **<font color="red">YearsInCurrentRole</font>** : Çalışanın mevcut roldeki yılları
#
# * **<font color="red">YearsSinceLastPromotion</font>** : Çalışanın son terfi yılından bu yana geçen yıllar
#
# * **<font color="red">YearsWithCurrManager</font>** : Çalışanın mevcut yöneticiyle geçirdiği yıllar

# %%
import pandas as pd
import numpy as np

import seaborn as sns
from matplotlib import pyplot as plt

# %%
pd.set_option('display.max_columns', None)
#we have different attributes for set_option

# %%
human_res = pd.read_csv("Human_Resources.csv")
human_res.head()
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate
# 0   41         5993.0       Yes      Travel_Rarely       1102  \
# 1   49            NaN        No  Travel_Frequently        279
# 2   37         2090.0       Yes      Travel_Rarely       1373
# 3   33         2909.0        No  Travel_Frequently       1392
# 4   27         3468.0        No      Travel_Rarely        591
#
#                Department  DistanceFromHome  Education EducationField
# 0                   Sales                 1          2  Life Sciences  \
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
#
#    EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate
# 0              1             1.0                        2  Female          94  \
# ...

# %%
human_res.tail()
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate
# 1465   36         2571.0        No  Travel_Frequently        884  \
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField
# 1465  Research & Development                23          2        Medical  \
# 1466  Research & Development                 6          1        Medical
# 1467  Research & Development                 4          3  Life Sciences
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EmployeeCount  EmployeeNumber  EnvironmentSatisfaction Gender
# ...

# %%
human_res.sample(5)
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate
# 95     54        13549.0        No      Travel_Rarely       1217  \
# 91     51         5441.0        No      Travel_Rarely        632
# 1055   34        17007.0        No  Travel_Frequently        829
# 954    42        17861.0        No         Non-Travel        495
# 335    40         7457.0        No      Travel_Rarely       1124
#
#                   Department  DistanceFromHome  Education    EducationField
# 95    Research & Development                 2          4  Technical Degree  \
# 91                     Sales                21          4         Marketing
# 1055  Research & Development                15          3           Medical
# 954   Research & Development                 2          1     Life Sciences
# 335                    Sales                 1          2           Medical
#
#       EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender
# ...

# %%
human_res.info()
#over18 and some other should have been changed object to int64
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   MonthlyIncome             1467 non-null   float64
#  2   Attrition                 1470 non-null   object
#  3   BusinessTravel            1470 non-null   object
#  4   DailyRate                 1470 non-null   int64
#  5   Department                1469 non-null   object
#  6   DistanceFromHome          1470 non-null   int64
#  7   Education                 1470 non-null   int64
#  8   EducationField            1469 non-null   object
#  9   EmployeeCount             1470 non-null   int64
#  10  EmployeeNumber            1469 non-null   float64
#  11  EnvironmentSatisfaction   1470 non-null   int64
#  12  Gender                    1469 non-null   object
# ...

# %%
human_res_null = human_res.isnull().sum()
human_res_null[human_res_null!=0]
# Out:
# MonthlyIncome        3
# Department           1
# EducationField       1
# EmployeeNumber       1
# Gender               1
# JobRole              1
# MaritalStatus        1
# MonthlyRate          2
# PercentSalaryHike    1
# PerformanceRating    1
# dtype: int64

# %%
human_res.shape
#we have 35 feature
#we have 1470 entry
# Out:
# (1470, 35)

# %%
human_res.columns
# Out:
# Index(['Age', 'MonthlyIncome', 'Attrition', 'BusinessTravel', 'DailyRate',
#        'Department', 'DistanceFromHome', 'Education', 'EducationField',
#        'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
human_res.select_dtypes("number").mean()
#suspicious values are standarthours, employeecount
#for nominal and ordinal types, mean calculuation have no meaning
# Out:
# Age                            36.923810
# MonthlyIncome                6505.155419
# DailyRate                     802.485714
# DistanceFromHome                9.192517
# Education                       2.912925
# EmployeeCount                   1.000000
# EmployeeNumber               1025.556161
# EnvironmentSatisfaction         2.721769
# HourlyRate                     65.891156
# JobInvolvement                  2.729932
# JobLevel                        2.063946
# JobSatisfaction                 2.728571
# MonthlyRate                 14310.966621
# NumCompaniesWorked              2.693197
# PercentSalaryHike              15.206263
# PerformanceRating               3.153165
# RelationshipSatisfaction        2.712245
# StandardHours                  80.000000
# StockOptionLevel                0.793878
# TotalWorkingYears              11.279592
# TrainingTimesLastYear           2.799320
# WorkLifeBalance                 2.761224
# YearsAtCompany                  7.008163
# ...

# %%
human_res.nunique()
#over 18, employeecount and standart hours have no unique entry, maybe we can drop them adding these information our report
# Out:
# Age                           43
# MonthlyIncome               1346
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1469
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyRate                 1425
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %%
human_res.select_dtypes("number").describe().T
# Out:
#                            count          mean          std     min      25%
# Age                       1470.0     36.923810     9.135373    18.0    30.00  \
# MonthlyIncome             1467.0   6505.155419  4711.297846  1009.0  2911.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1469.0   1025.556161   601.646166     1.0   492.00
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# ...

# %% [markdown]
# **PRACTICE OPPORTUNITY #1:**
# - **Calculate the mean, maximum and minimum employee age considered in this study using a different strategy**

# %%
get_min_max_mean = lambda nums: (nums.min(), nums.max(), nums.mean())

numbers = human_res["Age"]

min_val, max_val, mean_val = get_min_max_mean(numbers)

print("Minimum:", min_val)
print("Maximum:", max_val)
print("Mean:", mean_val)
# Out:
# Minimum: 18
# Maximum: 60
# Mean: 36.923809523809524

# %% [markdown]
# # CODING TASK #2. DEALING WITH MISSING DATA

# %% [markdown]
# - **Let's locate rows that have Null values**
#
# - **Notice Row index 6 has many missing values**
#
# - **Let's see the total number of missing elements per column**
#
# - **Drop any row that contains a Null value**
#
# - **Note that the size of the dataframe has been reduced by 7 elements from 1470 to 1463**
#
# - **Notice that row 1 for example is no longer existing!**
#
# - **Let's check if we still have any missing values**
#
# - **Let's explore an alternative (smarter) method to deal with missing values**
#
# - **Let's read the raw data again using Pandas as follows**
#
# - **Calculate the average monthly income**
#
# - **You can use Fillna to fill a given column with a certain value**

# %%
null_rows = human_res.isnull().any(axis=1)

rows_with_null = human_res[null_rows]
print(rows_with_null)
# Out:
#      Age  MonthlyIncome Attrition     BusinessTravel  DailyRate
# 1     49            NaN        No  Travel_Frequently        279  \
# 6     59            NaN        No      Travel_Rarely       1324
# 7     30         2693.0        No      Travel_Rarely       1358
# 17    22         2935.0        No         Non-Travel       1123
# 23    21         1232.0        No      Travel_Rarely        391
# 103   34         4809.0        No      Travel_Rarely        665
# 947   52            NaN       Yes      Travel_Rarely       1030
#
#                  Department  DistanceFromHome  Education EducationField
# 1    Research & Development                 8          1  Life Sciences  \
# 6    Research & Development                 3          3            NaN
# 7                       NaN                24          1  Life Sciences
# 17   Research & Development                16          2        Medical
# 23   Research & Development                15          2  Life Sciences
# ...

# %%
null_rows = human_res.isnull().sum(axis=1)
row_with_max_null = null_rows.idxmax()
print("Row with max null values:", row_with_max_null)
print("")
print(null_rows)
# Out:
# Row with max null values: 6
#
# 0       0
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Length: 1470, dtype: int64

# %%
null_rows[null_rows!=0]
# Out:
# 1      1
# 6      7
# 7      1
# 17     1
# 23     1
# 103    1
# 947    1
# dtype: int64

# %%
human_res_null = human_res.isnull().sum()
human_res_null[human_res_null!=0]
# Out:
# MonthlyIncome        3
# Department           1
# EducationField       1
# EmployeeNumber       1
# Gender               1
# JobRole              1
# MaritalStatus        1
# MonthlyRate          2
# PercentSalaryHike    1
# PerformanceRating    1
# dtype: int64

# %%
human_res.dropna(axis=0,inplace=True)

# %%
null_rows = human_res.isnull().sum(axis=1)

null_rows[null_rows!=0]
# Out:
# Series([], dtype: int64)

# %%
human_res.head(7)
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate
# 0   41         5993.0       Yes      Travel_Rarely       1102  \
# 2   37         2090.0       Yes      Travel_Rarely       1373
# 3   33         2909.0        No  Travel_Frequently       1392
# 4   27         3468.0        No      Travel_Rarely        591
# 5   32         3068.0        No  Travel_Frequently       1005
# 8   38         9526.0        No  Travel_Frequently        216
# 9   36         5237.0        No      Travel_Rarely       1299
#
#                Department  DistanceFromHome  Education EducationField
# 0                   Sales                 1          2  Life Sciences  \
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
# 5  Research & Development                 2          2  Life Sciences
# ...

# %%
human_res.shape
# Out:
# (1463, 35)

# %%
human_res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1463 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1463 non-null   int64
#  1   MonthlyIncome             1463 non-null   float64
#  2   Attrition                 1463 non-null   object
#  3   BusinessTravel            1463 non-null   object
#  4   DailyRate                 1463 non-null   int64
#  5   Department                1463 non-null   object
#  6   DistanceFromHome          1463 non-null   int64
#  7   Education                 1463 non-null   int64
#  8   EducationField            1463 non-null   object
#  9   EmployeeCount             1463 non-null   int64
#  10  EmployeeNumber            1463 non-null   float64
#  11  EnvironmentSatisfaction   1463 non-null   int64
#  12  Gender                    1463 non-null   object
#  13  HourlyRate                1463 non-null   int64
# ...

# %%
null_rows = human_res.isnull().sum(axis=1)
row_with_max_null = null_rows.idxmax()
print("Number of rows with null values:", row_with_max_null)
human_res_null = human_res.isnull().sum()
print("Number of columns with null values:", len(human_res_null[human_res_null!=0]))
# Out:
# Number of rows with null values: 0
# Number of columns with null values: 0

# %%
human_res_copy = pd.read_csv("Human_Resources.csv")
human_res_copy.head()
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate
# 0   41         5993.0       Yes      Travel_Rarely       1102  \
# 1   49            NaN        No  Travel_Frequently        279
# 2   37         2090.0       Yes      Travel_Rarely       1373
# 3   33         2909.0        No  Travel_Frequently       1392
# 4   27         3468.0        No      Travel_Rarely        591
#
#                Department  DistanceFromHome  Education EducationField
# 0                   Sales                 1          2  Life Sciences  \
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
#
#    EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate
# 0              1             1.0                        2  Female          94  \
# ...

# %%
income_mean = human_res_copy["MonthlyIncome"].mean()
human_res_copy["MonthlyIncome"].fillna(income_mean,inplace = True)

# %%
human_res_copy.head()
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate
# 0   41    5993.000000       Yes      Travel_Rarely       1102  \
# 1   49    6505.155419        No  Travel_Frequently        279
# 2   37    2090.000000       Yes      Travel_Rarely       1373
# 3   33    2909.000000        No  Travel_Frequently       1392
# 4   27    3468.000000        No      Travel_Rarely        591
#
#                Department  DistanceFromHome  Education EducationField
# 0                   Sales                 1          2  Life Sciences  \
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
#
#    EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate
# 0              1             1.0                        2  Female          94  \
# ...

# %%
human_res_null = human_res_copy.isnull().sum()
human_res_null[human_res_null!=0]
# Out:
# Department           1
# EducationField       1
# EmployeeNumber       1
# Gender               1
# JobRole              1
# MaritalStatus        1
# MonthlyRate          2
# PercentSalaryHike    1
# PerformanceRating    1
# dtype: int64

# %% [markdown]
# **PRACTICE OPPORTUNITY #2:**
# - **Calculate the median monthly rate. Use the calculated median values to fill out missing data. Confirm that the process is successful**

# %%
rate_median = human_res_copy["MonthlyRate"].median()
human_res_copy["MonthlyRate"].fillna(income_mean,inplace = True)

# %%
human_res_null = human_res_copy.isnull().sum()
human_res_null[human_res_null!=0]
# Out:
# Department           1
# EducationField       1
# EmployeeNumber       1
# Gender               1
# JobRole              1
# MaritalStatus        1
# PercentSalaryHike    1
# PerformanceRating    1
# dtype: int64

# %%
human_res_copy[["Department", "JobRole"]].value_counts()
# Out:
# Department              JobRole
# Sales                   Sales Executive              326
# Research & Development  Research Scientist           292
#                         Laboratory Technician        257
#                         Manufacturing Director       145
#                         Healthcare Representative    131
# Sales                   Sales Representative          83
# Research & Development  Research Director             80
#                         Manager                       54
# Human Resources         Human Resources               52
# Sales                   Manager                       37
# Human Resources         Manager                       11
# Name: count, dtype: int64

# %%
with pd.option_context('display.max_columns', None):
    display(human_res_copy.iloc[[7]])

#jobrole :  Laboratory Technician olanların hepsi departmen olarak Research & Development olduğu için 
# 7. indexi bununla doldurabiliriz
# Out:
#    Age  MonthlyIncome Attrition BusinessTravel  DailyRate Department
# 7   30         2693.0        No  Travel_Rarely       1358        NaN  \
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber
# 7                24          1  Life Sciences              1            11.0  \
#
#    EnvironmentSatisfaction Gender  HourlyRate  JobInvolvement  JobLevel
# 7                        4   Male          67               3         1  \
#
#                  JobRole  JobSatisfaction MaritalStatus  MonthlyRate
# 7  Laboratory Technician                3      Divorced      13335.0  \
#
#    NumCompaniesWorked Over18 OverTime  PercentSalaryHike  PerformanceRating
# 7                   1      Y       No               22.0                4.0  \
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel
# 7                         2             80                 1  \
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany
# ...

# %%
with pd.option_context('display.max_columns', None):
    display(human_res_copy[human_res_copy.isna().any(axis = 1)])
# Out:
#     Age  MonthlyIncome Attrition BusinessTravel  DailyRate
# 6    59    6505.155419        No  Travel_Rarely       1324  \
# 7    30    2693.000000        No  Travel_Rarely       1358
# 17   22    2935.000000        No     Non-Travel       1123
#
#                 Department  DistanceFromHome  Education EducationField
# 6   Research & Development                 3          3            NaN  \
# 7                      NaN                24          1  Life Sciences
# 17  Research & Development                16          2        Medical
#
#     EmployeeCount  EmployeeNumber  EnvironmentSatisfaction Gender  HourlyRate
# 6               1             NaN                        3    NaN          81  \
# 7               1            11.0                        4   Male          67
# 17              1            22.0                        4   Male          96
#
#     JobInvolvement  JobLevel                JobRole  JobSatisfaction
# ...

# %%
human_res_copy.at[7, "Department"]
# Out:
# nan

# %%
human_res_copy.at[7, "Department"] = "Research & Development"

# %%
human_res_copy.at[7, "Department"]
# Out:
# 'Research & Development'

# %%
with pd.option_context('display.max_columns', None):
    display(human_res_copy[human_res_copy.isna().any(axis = 1)])
# Out:
#     Age  MonthlyIncome Attrition BusinessTravel  DailyRate
# 6    59    6505.155419        No  Travel_Rarely       1324  \
# 17   22    2935.000000        No     Non-Travel       1123
#
#                 Department  DistanceFromHome  Education EducationField
# 6   Research & Development                 3          3            NaN  \
# 17  Research & Development                16          2        Medical
#
#     EmployeeCount  EmployeeNumber  EnvironmentSatisfaction Gender  HourlyRate
# 6               1             NaN                        3    NaN          81  \
# 17              1            22.0                        4   Male          96
#
#     JobInvolvement  JobLevel                JobRole  JobSatisfaction
# 6                4         1                    NaN                1  \
# 17               4         1  Laboratory Technician                4
#
#    MaritalStatus  MonthlyRate  NumCompaniesWorked Over18 OverTime
# ...

# %% [markdown]
# # CODING TASK #3: PERFORM ONE-HOT ENCODING [OPTIONAL]

# %% [markdown]
# - **Import the Human Resources data and remove all missing values**
# - **How many unique categories exist in the Education Field column?**
# - **Perform one hot encoding to the Education Field column**

# %% [markdown]
# ![2.png](data:image/png;base64,...)

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %%
# Let's read a CSV file using Pandas as follows
human_res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1463 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1463 non-null   int64
#  1   MonthlyIncome             1463 non-null   float64
#  2   Attrition                 1463 non-null   object
#  3   BusinessTravel            1463 non-null   object
#  4   DailyRate                 1463 non-null   int64
#  5   Department                1463 non-null   object
#  6   DistanceFromHome          1463 non-null   int64
#  7   Education                 1463 non-null   int64
#  8   EducationField            1463 non-null   object
#  9   EmployeeCount             1463 non-null   int64
#  10  EmployeeNumber            1463 non-null   float64
#  11  EnvironmentSatisfaction   1463 non-null   int64
#  12  Gender                    1463 non-null   object
#  13  HourlyRate                1463 non-null   int64
# ...

# %%
human_res['BusinessTravel'].unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
human_res['BusinessTravel']
# Out:
# 0           Travel_Rarely
# 2           Travel_Rarely
# 3       Travel_Frequently
# 4           Travel_Rarely
# 5       Travel_Frequently
#               ...
# 1465    Travel_Frequently
# 1466        Travel_Rarely
# 1467        Travel_Rarely
# 1468    Travel_Frequently
# 1469        Travel_Rarely
# Name: BusinessTravel, Length: 1463, dtype: object

# %%
BusinessTravel_Encoded = pd.get_dummies(human_res['BusinessTravel'],dtype=float)
print(BusinessTravel_Encoded)
# Out:
#       Non-Travel  Travel_Frequently  Travel_Rarely
# 0            0.0                0.0            1.0
# 2            0.0                0.0            1.0
# 3            0.0                1.0            0.0
# 4            0.0                0.0            1.0
# 5            0.0                1.0            0.0
# ...          ...                ...            ...
# 1465         0.0                1.0            0.0
# 1466         0.0                0.0            1.0
# 1467         0.0                0.0            1.0
# 1468         0.0                1.0            0.0
# 1469         0.0                0.0            1.0
#
# [1463 rows x 3 columns]

# %%
BusinessTravel_Encoded.shape
# Out:
# (1463, 3)

# %% [markdown]
# # CODING TASK #4: PERFORM SCALING (NORMALIZATION & STANDARDIZATION) [OPTIONAL]

# %%
human_res['Age'].values
# Out:
# array([41, 37, 33, ..., 27, 49, 34])

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Normalization is conducted to make feature values range from 0 to 1
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
human_res['Age'] = scaler.fit_transform(human_res['Age'].values.reshape(-1,1))

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
for i in human_res.select_dtypes("number").columns:
    human_res[i] = scaler.fit_transform(human_res[i].values.reshape(-1,1))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
human_res.describe().T
# Out:
#                            count          mean       std       min       25%
# Age                       1463.0  1.165620e-16  1.000342 -2.078460 -0.760057  \
# MonthlyIncome             1463.0 -1.214188e-18  1.000342 -1.168520 -0.763271
# DailyRate                 1463.0  4.856751e-17  1.000342 -1.735853 -0.835828
# DistanceFromHome          1463.0  5.828102e-17  1.000342 -1.009355 -0.886020
# Education                 1463.0 -2.768348e-16  1.000342 -1.873103 -0.895454
# EmployeeCount             1463.0  0.000000e+00  0.000000  0.000000  0.000000
# EmployeeNumber            1463.0  0.000000e+00  1.000342 -1.713292 -0.888922
# EnvironmentSatisfaction   1463.0  1.542019e-16  1.000342 -1.574475 -0.659679
# HourlyRate                1463.0 -1.019918e-16  1.000342 -1.764281 -0.878711
# JobInvolvement            1463.0  9.227828e-17  1.000342 -2.430073 -1.023745
# JobLevel                  1463.0  2.064119e-17  1.000342 -0.962770 -0.962770
# ...

# %%
human_res['Age']
# Out:
# 0       0.448479
# 2       0.009012
# 3      -0.430456
# 4      -1.089658
# 5      -0.540323
#           ...
# 1465   -0.100855
# 1466    0.228746
# 1467   -1.089658
# 1468    1.327415
# 1469   -0.320589
# Name: Age, Length: 1463, dtype: float64

# %%
human_res.describe().T
# Out:
#                            count          mean       std       min       25%
# Age                       1463.0  1.165620e-16  1.000342 -2.078460 -0.760057  \
# MonthlyIncome             1463.0 -1.214188e-18  1.000342 -1.168520 -0.763271
# DailyRate                 1463.0  4.856751e-17  1.000342 -1.735853 -0.835828
# DistanceFromHome          1463.0  5.828102e-17  1.000342 -1.009355 -0.886020
# Education                 1463.0 -2.768348e-16  1.000342 -1.873103 -0.895454
# EmployeeCount             1463.0  0.000000e+00  0.000000  0.000000  0.000000
# EmployeeNumber            1463.0  0.000000e+00  1.000342 -1.713292 -0.888922
# EnvironmentSatisfaction   1463.0  1.542019e-16  1.000342 -1.574475 -0.659679
# HourlyRate                1463.0 -1.019918e-16  1.000342 -1.764281 -0.878711
# JobInvolvement            1463.0  9.227828e-17  1.000342 -2.430073 -1.023745
# JobLevel                  1463.0  2.064119e-17  1.000342 -0.962770 -0.962770
# ...

# %% [markdown]
# **PRACTICE OPPORTUNITY #4 [OPTIONAL]:**
# - **Perform feature scaling by performing standardization (Recall that Standardization is conducted to transform the data to have a mean of zero and standard deviation of 1.**
# - **Perform a sanity check to ensure that the transformation was successful**

# %% [markdown]
# # CODING TASK #5. PANDAS OPERATIONS/FILTERING

# %%
# Let's read a CSV file using Pandas as follows
human_res_2 = pd.read_csv('Human_Resources.csv')
human_res_2.head()
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate
# 0   41         5993.0       Yes      Travel_Rarely       1102  \
# 1   49            NaN        No  Travel_Frequently        279
# 2   37         2090.0       Yes      Travel_Rarely       1373
# 3   33         2909.0        No  Travel_Frequently       1392
# 4   27         3468.0        No      Travel_Rarely        591
#
#                Department  DistanceFromHome  Education EducationField
# 0                   Sales                 1          2  Life Sciences  \
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
#
#    EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate
# 0              1             1.0                        2  Female          94  \
# ...

# %% [markdown]
# - **Pick certain rows that satisfy a certain criteria**
#
# - **Pick certain rows that satisfy 2 or more critirea**
#
# - **values that fall between a given range**

# %%
human_res_2[human_res_2["Department"] == "Research & Development"]
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate
# 1      49            NaN        No  Travel_Frequently        279  \
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# 5      32         3068.0        No  Travel_Frequently       1005
# ...   ...            ...       ...                ...        ...
# 1463   31         9936.0        No         Non-Travel        325
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField
# 1     Research & Development                 8          1  Life Sciences  \
# ...

# %%
human_res_2[(human_res_2["Department"] == "Research & Development")&(human_res_2["Age"] == 32)]
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate
# 5      32         3068.0        No  Travel_Frequently       1005  \
# 16     32         3298.0        No      Travel_Rarely        334
# 26     32         3919.0       Yes  Travel_Frequently       1125
# 60     32         6162.0        No      Travel_Rarely        427
# 73     32         6220.0        No      Travel_Rarely        548
# 101    32         2956.0        No      Travel_Rarely        827
# 140    32         4200.0       Yes      Travel_Rarely       1033
# 169    32         3038.0        No      Travel_Rarely        120
# 239    32         3730.0       Yes      Travel_Rarely        515
# 260    32         2794.0        No  Travel_Frequently       1311
# 262    32         2176.0        No      Travel_Rarely        128
# 322    32         5055.0        No      Travel_Rarely       1018
# 351    32         2370.0        No      Travel_Rarely       1062
# ...

# %%
human_res_2.loc[100:150]
# Out:
#      Age  MonthlyIncome Attrition     BusinessTravel  DailyRate
# 100   37         2073.0       Yes      Travel_Rarely        807  \
# 101   32         2956.0        No      Travel_Rarely        827
# 102   20         2926.0       Yes  Travel_Frequently        871
# 103   34         4809.0        No      Travel_Rarely        665
# 104   37         5163.0        No         Non-Travel       1040
# 105   59        18844.0        No         Non-Travel       1420
# 106   50        18172.0        No  Travel_Frequently       1115
# 107   25         5744.0       Yes      Travel_Rarely        240
# 108   25         2889.0        No      Travel_Rarely       1280
# 109   22         2871.0        No      Travel_Rarely        534
# 110   51         7484.0        No  Travel_Frequently       1456
# 111   34         6074.0       Yes  Travel_Frequently        658
# 112   54        17328.0        No         Non-Travel        142
# 113   24         2774.0        No      Travel_Rarely       1127
# ...

# %% [markdown]
# **PRACTICE OPPORTUNITY #5:**
# - **Using "hr_df" DataFrame, leverage pandas operations to only select high DailyRate individuals (1450+)**
# - **What is the combined Daily Rate for all employees with 1450+?**

# %%
human_res_2[human_res_2["DailyRate"] > 1450]
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate
# 31     44         6465.0        No      Travel_Rarely       1459  \
# 52     44         5454.0        No      Travel_Rarely       1488
# 110    51         7484.0        No  Travel_Frequently       1456
# 117    36         9738.0        No  Travel_Frequently       1467
# 155    29         4319.0        No         Non-Travel       1496
# 165    50        19926.0        No      Travel_Rarely       1452
# 172    36         2088.0        No  Travel_Frequently       1480
# 213    51        12490.0        No      Travel_Rarely       1469
# 266    31         5582.0        No      Travel_Rarely       1463
# 278    26         6397.0        No  Travel_Frequently       1479
# 302    28         5661.0        No      Travel_Rarely       1476
# 329    47        18300.0        No      Travel_Rarely       1482
# 373    27         3816.0        No      Travel_Rarely       1469
# ...

# %%
human_res_2[human_res_2["DailyRate"] > 1450]["DailyRate"].sum()
# Out:
# 70849

# %% [markdown]
# # CODING TASK #6: PERFORM BASIC EDA ON BOTH CLASSES

# %% [markdown]
# - **It makes sense to drop 'EmployeeCount', 'Standardhours' and 'Over18' since they do not change from one employee to the other**
# - **Let's see how many employees left the company! Let's drop 'EmployeeNumber' as well**
# - **Let's see how many employees left the company!**
# - **View employees who left**

# %%
human_res_2.drop(['EmployeeCount','StandardHours','Over18'],axis=1,inplace=True)
human_res_2.head()
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate
# 0   41         5993.0       Yes      Travel_Rarely       1102  \
# 1   49            NaN        No  Travel_Frequently        279
# 2   37         2090.0       Yes      Travel_Rarely       1373
# 3   33         2909.0        No  Travel_Frequently       1392
# 4   27         3468.0        No      Travel_Rarely        591
#
#                Department  DistanceFromHome  Education EducationField
# 0                   Sales                 1          2  Life Sciences  \
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
#
#    EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate
# 0             1.0                        2  Female          94  \
# ...

# %%
human_res_2.shape
# Out:
# (1470, 32)

# %%
human_res_2.drop(['EmployeeNumber'],axis=1,inplace=True)
human_res_2.head()
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate
# 0   41         5993.0       Yes      Travel_Rarely       1102  \
# 1   49            NaN        No  Travel_Frequently        279
# 2   37         2090.0       Yes      Travel_Rarely       1373
# 3   33         2909.0        No  Travel_Frequently       1392
# 4   27         3468.0        No      Travel_Rarely        591
#
#                Department  DistanceFromHome  Education EducationField
# 0                   Sales                 1          2  Life Sciences  \
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel
# 0                        2  Female          94               3         2  \
# ...

# %%
human_res_2.shape
# Out:
# (1470, 31)

# %%
human_res_2["Attrition"].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
human_res_2[human_res_2["Attrition"] == "Yes"]
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate
# 0      41         5993.0       Yes      Travel_Rarely       1102  \
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 14     28         2028.0       Yes      Travel_Rarely        103
# 21     36         3407.0       Yes      Travel_Rarely       1218
# 24     34         2960.0       Yes      Travel_Rarely        699
# ...   ...            ...       ...                ...        ...
# 1438   23         1790.0       Yes  Travel_Frequently        638
# 1442   29         4787.0       Yes      Travel_Rarely       1092
# 1444   56         2339.0       Yes      Travel_Rarely        310
# 1452   50         6728.0       Yes  Travel_Frequently        878
# 1461   50        10854.0       Yes      Travel_Rarely        410
#
#                   Department  DistanceFromHome  Education    EducationField
# 0                      Sales                 1          2     Life Sciences  \
# ...

# %% [markdown]
# **PRACTICE OPPORTUNITY #6:**
# - **Filter the hr_df to only include the employees who stayed in the company**
# - **Generate statistical summary for employees who stayed**
# - **Compare both statistical summaries. What do you infer from the data?**

# %%
human_res_2[human_res_2["Attrition"] == "No"]
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate
# 1      49            NaN        No  Travel_Frequently        279  \
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# 5      32         3068.0        No  Travel_Frequently       1005
# 6      59            NaN        No      Travel_Rarely       1324
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField
# 1     Research & Development                 8          1  Life Sciences  \
# ...

# %%
human_res_2[human_res_2["Attrition"] == "No"].describe().T
# Out:
#                            count          mean          std     min     25%
# Age                       1233.0     37.561233     8.888360    18.0    31.0  \
# MonthlyIncome             1231.0   6837.504468  4820.415800  1051.0  3211.5
# DailyRate                 1233.0    812.504461   403.208379   102.0   477.0
# DistanceFromHome          1233.0      8.915653     8.012633     1.0     2.0
# Education                 1233.0      2.927007     1.027002     1.0     2.0
# EnvironmentSatisfaction   1233.0      2.771290     1.071132     1.0     2.0
# HourlyRate                1233.0     65.952149    20.380754    30.0    48.0
# JobInvolvement            1233.0      2.770479     0.692050     1.0     2.0
# JobLevel                  1233.0      2.145985     1.117933     1.0     1.0
# JobSatisfaction           1233.0      2.778589     1.093277     1.0     2.0
# MonthlyRate               1231.0  14263.154346  7106.411508  2094.0  7961.5
# ...

# %%
human_res_2[human_res_2["Attrition"] == "Yes"].describe().T
# Out:
#                           count          mean          std     min     25%
# Age                       237.0     33.607595     9.689350    18.0    28.0  \
# MonthlyIncome             236.0   4771.588983  3640.097444  1009.0  2371.5
# DailyRate                 237.0    750.362869   401.899519   103.0   408.0
# DistanceFromHome          237.0     10.632911     8.452525     1.0     3.0
# Education                 237.0      2.839662     1.008244     1.0     2.0
# EnvironmentSatisfaction   237.0      2.464135     1.169791     1.0     1.0
# HourlyRate                237.0     65.573840    20.099958    31.0    50.0
# JobInvolvement            237.0      2.518987     0.773405     1.0     2.0
# JobLevel                  237.0      1.637131     0.940594     1.0     1.0
# JobSatisfaction           237.0      2.468354     1.118058     1.0     1.0
# MonthlyRate               237.0  14559.308017  7208.153264  2326.0  8870.0
# ...

# %%
plt.figure(figsize = (15, 8))
sns.countplot(data = human_res_2, x = "YearsAtCompany", hue = "Attrition");

# %%
plt.figure(figsize = (8, 6))
sns.countplot(data = human_res_2, x = "JobSatisfaction", hue = "Attrition");

# %% [markdown]
# # CODING TASK #7. PANDAS WITH FUNCTIONS

# %%
# Let's read a CSV file using Pandas as follows
hr_df = pd.read_csv('Human_Resources.csv')
hr_df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate
# 0      41         5993.0       Yes      Travel_Rarely       1102  \
# 1      49            NaN        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField
# 0                      Sales                 1          2  Life Sciences  \
# ...

# %% [markdown]
# - **Let's assume the daily rate has increased by 10%**
# - **Define a function that increases all clients networth by a fixed value of 10% (for simplicity sake)**
# - **assume that net worth increased by 10%**
# - **You can apply a function to the DataFrame**

# %%
hr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   MonthlyIncome             1467 non-null   float64
#  2   Attrition                 1470 non-null   object
#  3   BusinessTravel            1470 non-null   object
#  4   DailyRate                 1470 non-null   int64
#  5   Department                1469 non-null   object
#  6   DistanceFromHome          1470 non-null   int64
#  7   Education                 1470 non-null   int64
#  8   EducationField            1469 non-null   object
#  9   EmployeeCount             1470 non-null   int64
#  10  EmployeeNumber            1469 non-null   float64
#  11  EnvironmentSatisfaction   1470 non-null   int64
#  12  Gender                    1469 non-null   object
# ...

# %%
hr_df["increased_daily_rate"] = hr_df["DailyRate"].apply(lambda x: x * 1.1)

# %%
hr_df.head()
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate
# 0   41         5993.0       Yes      Travel_Rarely       1102  \
# 1   49            NaN        No  Travel_Frequently        279
# 2   37         2090.0       Yes      Travel_Rarely       1373
# 3   33         2909.0        No  Travel_Frequently       1392
# 4   27         3468.0        No      Travel_Rarely        591
#
#                Department  DistanceFromHome  Education EducationField
# 0                   Sales                 1          2  Life Sciences  \
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
#
#    EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate
# 0              1             1.0                        2  Female          94  \
# ...

# %% [markdown]
# **PRACTICE OPPORTUNITY #7:**
# - **Define a function that doubles the DailyRate and adds $100**
# - **Apply the function to the DataFrame**
# - **Calculate the updated total Daily Rate of all employees combined**

# %%
hr_df["increased_daily_rate_2"] = hr_df["DailyRate"].apply(lambda x: x * 2 + 100)

# %%
hr_df.head()
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate
# 0   41         5993.0       Yes      Travel_Rarely       1102  \
# 1   49            NaN        No  Travel_Frequently        279
# 2   37         2090.0       Yes      Travel_Rarely       1373
# 3   33         2909.0        No  Travel_Frequently       1392
# 4   27         3468.0        No      Travel_Rarely        591
#
#                Department  DistanceFromHome  Education EducationField
# 0                   Sales                 1          2  Life Sciences  \
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
#
#    EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate
# 0              1             1.0                        2  Female          94  \
# ...

# %% [markdown]
# # CODING TASK #8: HISTOGRAM AND CORRELATION

# %% [markdown]
# - **Several features such as 'MonthlyIncome' and 'TotalWorkingYears' are tail heavy**
# - **Job level is strongly correlated with total working hours**
# - **Monthly income is strongly correlated with Job level**
# - **Monthly income is strongly correlated with total working hours**
# - **Age is strongly correlated with monthly income**

# %%
fig, ax = plt.subplots(figsize=(10, 8))

sns.heatmap(hr_df[["MonthlyIncome","TotalWorkingYears","JobLevel","Age"]].corr(),annot=True, ax=ax, cmap='YlOrRd');
#Age is correlated with total working years
#MonthlyIncome and Job level are strongly correlated

# %%
sns.displot(hr_df["MonthlyIncome"],kde = True);

# %%
sns.displot(hr_df["TotalWorkingYears"],kde = True);

# %% [markdown]
# **PRACTICE OPPORTUNITY #8:**
# - **Change the color of the heatmap [External Research is Required]**

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(hr_df[["MonthlyIncome","TotalWorkingYears","JobLevel","Age"]].corr(), annot = True, cmap = "viridis_r");

# %% [markdown]
# # EXCELLENT JOB!

# %% [markdown]
# # FINAL CAPSTONE PROJECT OVERVIEW

# %% [markdown]
# - In this project, we will perform basic Exploratory Data Analysis (EDA) on the Kyphosis disease Dataset.
# - Kyphosis is an abnormally excessive convex curvature of the spine.
# - Dataset contains 81 rows and 4 columns representing data on children who have had corrective spinal surgery.
#     - INPUTS: 1. Age: in months, 2. Number: the number of vertebrae involved, 3. Start: the number of the first (topmost) vertebra operated on.
#     - OUTPUTS: Kyphosis which represents a factor with levels absent present indicating if a kyphosis (a type of deformation) was present after the operation.
# - Using the “kyphosis.csv" included in the course package, write a python script to perform the following tasks:
#     1. Import the “kyphosis.csv" file using Pandas
#     2. Perform basic Exploratory Data Analysis (EDA) on the data
#     3. List the average, minimum and maximum age (in years) considered in this study using 2 methods
#     4. Plot the correlation matrix
#     5. Convert the age column datatype from int64 to float64
#     6. Define a function that converts age from months to years
#     7. Apply the function to the “Age” column and add the results into a new column entitled “Age in Years”
#     8. What are the features of the oldest and youngest child in this study?
#     9. Scale the raw Age column (in months) using both standardization and Normalization. Perform a sanity check.
#     10. Normalization is conducted on the 'Age' column to make feature values range from 0 to 1.

# %%
kyphos = pd.read_csv("kyphosis.csv")
kyphos.head()
# Out:
#   Kyphosis  Age  Number  Start
# 0   absent   71       3      5
# 1   absent  158       3     14
# 2  present  128       4      5
# 3   absent    2       5      1
# 4   absent    1       4     15

# %%
kyphos.shape
# Out:
# (81, 4)

# %%
kyphos.describe().T
# Out:
#         count       mean        std  min   25%   50%    75%    max
# Age      81.0  83.654321  58.104251  1.0  26.0  87.0  130.0  206.0
# Number   81.0   4.049383   1.619423  2.0   3.0   4.0    5.0   10.0
# Start    81.0  11.493827   4.883962  1.0   9.0  13.0   16.0   18.0

# %%
kyphos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Kyphosis  81 non-null     object
#  1   Age       81 non-null     int64
#  2   Number    81 non-null     int64
#  3   Start     81 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 2.7+ KB

# %%
kyphos.nunique()
# Out:
# Kyphosis     2
# Age         64
# Number       8
# Start       16
# dtype: int64

# %%
get_min_max_mean = lambda nums: (nums.min(), nums.max(), nums.mean())

numbers = kyphos["Age"]/12
kyphos["Age in Years"] = kyphos["Age"].apply(lambda x: round(x / 12, 1)) 

min_val, max_val, mean_val = get_min_max_mean(numbers)

print("Minimum Age(year):", min_val)
print("Maximum Age(year):", max_val)
print("Mean Age(year):", mean_val)
# Out:
# Minimum Age(year): 0.08333333333333333
# Maximum Age(year): 17.166666666666668
# Mean Age(year): 6.971193415637861

# %%
fig, ax = plt.subplots(figsize=(10, 8))

sns.heatmap(kyphos[["Age","Number","Start"]].corr(),annot=True, ax=ax, cmap='YlOrRd');

# %%
kyphos["Age"] = kyphos["Age"].astype(float)

# %%
kyphos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Kyphosis      81 non-null     object
#  1   Age           81 non-null     float64
#  2   Number        81 non-null     int64
#  3   Start         81 non-null     int64
#  4   Age in Years  81 non-null     float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 3.3+ KB

# %%
kyphos.head()
# Out:
#   Kyphosis    Age  Number  Start  Age in Years
# 0   absent   71.0       3      5           5.9
# 1   absent  158.0       3     14          13.2
# 2  present  128.0       4      5          10.7
# 3   absent    2.0       5      1           0.2
# 4   absent    1.0       4     15           0.1

# %%
kyphos[(kyphos["Age"] == kyphos["Age"].min()) | (kyphos["Age"] == kyphos["Age"].max())]
#Early ages kyphosis is absent after the surgery
# Out:
#    Kyphosis    Age  Number  Start  Age in Years
# 4    absent    1.0       4     15           0.1
# 5    absent    1.0       2     16           0.1
# 13   absent    1.0       4     12           0.1
# 15   absent    1.0       3     16           0.1
# 36   absent    1.0       3      9           0.1
# 73   absent  206.0       4     10          17.2

# %%
scaler = MinMaxScaler()
kyphos['Age'] = scaler.fit_transform(kyphos['Age'].values.reshape(-1,1))

# %%
kyphos.head()
# Out:
#   Kyphosis       Age  Number  Start  Age in Years
# 0   absent  0.341463       3      5           5.9
# 1   absent  0.765854       3     14          13.2
# 2  present  0.619512       4      5          10.7
# 3   absent  0.004878       5      1           0.2
# 4   absent  0.000000       4     15           0.1

# %%
#Scale the raw Age column (in months) using both standardization and Normalization. Perform a sanity check.
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
kyphos["scale_AgeMonth"] = StandardScaler().fit_transform(kyphos.Age.values.reshape(-1, 1))

# %%
kyphos["scale_AgeYear"] = StandardScaler().fit_transform(kyphos["Age in Years"].values.reshape(-1, 1))

# %%
kyphos["scale_AgeMonth_norm"] = MinMaxScaler().fit_transform(kyphos.Age.values.reshape(-1, 1))

# %%
kyphos["scale_AgeYear_norm"] = MinMaxScaler().fit_transform(kyphos["Age in Years"].values.reshape(-1, 1))

# %%
kyphos.head()
# Out:
#   Kyphosis       Age  Number  Start  Age in Years  scale_AgeMonth
# 0   absent  0.341463       3      5           5.9       -0.219143  \
# 1   absent  0.765854       3     14          13.2        1.287494
# 2  present  0.619512       4      5          10.7        0.767964
# 3   absent  0.004878       5      1           0.2       -1.414063
# 4   absent  0.000000       4     15           0.1       -1.431381
#
#    scale_AgeYear  scale_AgeMonth_norm  scale_AgeYear_norm
# 0      -0.223052             0.341463            0.339181
# 1       1.294678             0.765854            0.766082
# 2       0.774907             0.619512            0.619883
# 3      -1.408129             0.004878            0.005848
# 4      -1.428920             0.000000            0.000000

# %% [markdown]
# # Great Job!

# %% [markdown]
# ![logo-2.png](attachment:logo-2.png)
